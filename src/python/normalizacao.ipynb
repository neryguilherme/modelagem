# %% [markdown]
# # Normalizacao

# %%
# pip install pandas numpy pyarrow duckdb sqlalchemy pymysql

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import gc
import duckdb
from sqlalchemy import create_engine

# %% [markdown]
# ### Carregando base de dados
# - Despesas 2025.1 (raw/receitas-2025.csv) + filtro para o primeiro semestre

# %%
df_despesas = pd.read_csv('../raw/despesas-2025.csv', sep=';')

# %%
print(df_despesas.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2387532 entries, 0 to 2387531
# Data columns (total 40 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   municipio                       str
#  1   codigo_unidade_gestora          float64
#  2   descricao_unidade_gestora       str
#  3   numero_empenho                  int64
#  4   data_empenho                    str
#  5   mes                             str
#  6   cpf_cnpj                        int64
#  7   nome_credor                     str
#  8   valor_empenhado                 str
#  9   valor_liquidado                 str
#  10  valor_pago                      str
#  11  codigo_unidade_orcamentaria     int64
#  12  descricao_unidade_orcamentaria  str
#  13  codigo_funcao                   int64
#  14  funcao                          str
#  15  codigo_subfuncao                int64
#  16  subfuncao                       str
#  17  codigo_programa                 int64
#  18  programa                        str
#  19  codigo_acao                     int64
#  20  acao                            str
#  21  codigo_categoria_economica      int64
#  22  categoria_economica             str
#  23  codigo_natureza                 int64
#  24  grupo_natureza_despesa          str
#  25  codigo_modalidade_aplicacao     int64
#  26  modalidade_aplicacao            str
#  27  codigo_elemento_despesa         int64
#  28  elemento_despesa                str
#  29  codigo_subelemento              int64
#  30  codigo_subelemento_exibicao     str
#  31  numero_licitacao                int64
#  32  modalidade_licitacao            str
#  33  numero_obra                     int64
#  34  historico                       str
#  35  codigo_fonte_recurso            int64
#  36  descricao_fonte_recurso         str
#  37  ano_fonte                       int64
#  38  co                              float64
#  39  descricao_co                    str
# dtypes: float64(2), int64(16), str(22)
# memory usage: 2.3 GB
# None

# %%
display(df_despesas[df_despesas['cpf_cnpj'] == 17436435])
# Out:
#         municipio  codigo_unidade_gestora         descricao_unidade_gestora  \
# 535343   Soledade                201209.0  Prefeitura Municipal de Soledade
# 536615   Soledade                201209.0  Prefeitura Municipal de Soledade
# 648506   Soledade                201209.0  Prefeitura Municipal de Soledade
# 906563   Soledade                201209.0  Prefeitura Municipal de Soledade
# 1131384  Soledade                201209.0  Prefeitura Municipal de Soledade
# 1263324  Soledade                201209.0  Prefeitura Municipal de Soledade
# 1378296  Soledade                201209.0  Prefeitura Municipal de Soledade
# 1743512  Soledade                201209.0  Prefeitura Municipal de Soledade
# 1914405  Soledade                201209.0  Prefeitura Municipal de Soledade
# 2142795  Soledade                201209.0  Prefeitura Municipal de Soledade
# 2176652  Soledade                201209.0  Prefeitura Municipal de Soledade
#
#          numero_empenho data_empenho          mes  cpf_cnpj  \
# 535343             2071   2025-03-28     03-Março  17436435
# 536615             2625   2025-04-11     04-Abril  17436435
# 648506             3509   2025-05-09      05-Maio  17436435
# 906563             4696   2025-06-11     06-Junho  17436435
# 1131384            5250   2025-06-30     06-Junho  17436435
# 1263324            6381   2025-07-31     07-Julho  17436435
# 1378296            7129   2025-08-27    08-Agosto  17436435
# 1743512            8194   2025-09-30  09-Setembro  17436435
# 1914405            9155   2025-10-30   10-Outubro  17436435
# 2142795           10531   2025-12-09  12-Dezembro  17436435
# 2176652           10997   2025-12-12  12-Dezembro  17436435
#
#                           nome_credor valor_empenhado valor_liquidado  ...  \
# 535343   ASTROGILDO BATISTA GUIMARAES          430,08          430,08  ...
# 536615   ASTROGILDO BATISTA GUIMARAES          430,08          430,08  ...
# 648506   ASTROGILDO BATISTA GUIMARAES          430,08          430,08  ...
# 906563   ASTROGILDO BATISTA GUIMARAES          430,08          430,08  ...
# 1131384  ASTROGILDO BATISTA GUIMARAES          430,08          430,08  ...
# 1263324  ASTROGILDO BATISTA GUIMARAES          430,08          430,08  ...
# 1378296  ASTROGILDO BATISTA GUIMARAES          430,08          430,08  ...
# 1743512  ASTROGILDO BATISTA GUIMARAES          438,08          438,08  ...
# 1914405  ASTROGILDO BATISTA GUIMARAES          438,08          438,08  ...
# 2142795  ASTROGILDO BATISTA GUIMARAES          430,08          430,08  ...
# 2176652  ASTROGILDO BATISTA GUIMARAES          430,08          430,08  ...
#
#         codigo_subelemento_exibicao  numero_licitacao modalidade_licitacao  \
# 535343           LOCAÇÃO DE IMÓVEIS                 0        Sem Licitação
# 536615           LOCAÇÃO DE IMÓVEIS                 0        Sem Licitação
# 648506           LOCAÇÃO DE IMÓVEIS                 0        Sem Licitação
# 906563           LOCAÇÃO DE IMÓVEIS                 0        Sem Licitação
# 1131384          LOCAÇÃO DE IMÓVEIS                 0        Sem Licitação
# 1263324          LOCAÇÃO DE IMÓVEIS                 0        Sem Licitação
# 1378296          LOCAÇÃO DE IMÓVEIS                 0        Sem Licitação
# 1743512          LOCAÇÃO DE IMÓVEIS                 0        Sem Licitação
# 1914405          LOCAÇÃO DE IMÓVEIS                 0        Sem Licitação
# 2142795          LOCAÇÃO DE IMÓVEIS                 0        Sem Licitação
# 2176652          LOCAÇÃO DE IMÓVEIS                 0        Sem Licitação
#
#          numero_obra                                          historico  \
# 535343             0  VALOR QUE SE EMPENHA REFERENTE AO PAGAMENTO DE...
# 536615             0  VALOR QUE SE EMPENHA REFERENTE AO PAGAMENTO DE...
# 648506             0  VALOR QUE SE EMPENHA REFERENTE AO PAGAMENTO DE...
# 906563             0  VALOR QUE SE EMPENHA REFERENTE AO PAGAMENTO DE...
# 1131384            0  VALOR QUE SE EMPENHA REFERENTE AO PAGAMENTO DE...
# 1263324            0  VALOR QUE SE EMPENHA REFERENTE AO PAGAMENTO DE...
# 1378296            0  VALOR QUE SE EMPENHA REFERENTE AO PAGAMENTO DE...
# 1743512            0  VALOR QUE SE EMPENHA REFERENTE AO PAGAMENTO DE...
# 1914405            0  VALOR QUE SE EMPENHA REFERENTE AO PAGAMENTO DE...
# 2142795            0  VALOR QUE SE EMPENHA REFERENTE AO PAGAMENTO DE...
# 2176652            0  VALOR QUE SE EMPENHA REFERENTE AO PAGAMENTO DE...
#
#          codigo_fonte_recurso              descricao_fonte_recurso  ano_fonte  \
# 535343                    500  Recursos não vinculados de Impostos          1
# 536615                    500  Recursos não vinculados de Impostos          1
# 648506                    500  Recursos não vinculados de Impostos          1
# 906563                    500  Recursos não vinculados de Impostos          1
# 1131384                   500  Recursos não vinculados de Impostos          1
# 1263324                   500  Recursos não vinculados de Impostos          1
# 1378296                   500  Recursos não vinculados de Impostos          1
# 1743512                   500  Recursos não vinculados de Impostos          1
# 1914405                   500  Recursos não vinculados de Impostos          1
# 2142795                   500  Recursos não vinculados de Impostos          1
# 2176652                   500  Recursos não vinculados de Impostos          1
#
#              co                                       descricao_co
# 535343   1002.0  Identificação das despesas com ações e serviço...
# 536615   1002.0  Identificação das despesas com ações e serviço...
# 648506   1002.0  Identificação das despesas com ações e serviço...
# 906563   1002.0  Identificação das despesas com ações e serviço...
# 1131384  1002.0  Identificação das despesas com ações e serviço...
# 1263324  1002.0  Identificação das despesas com ações e serviço...
# 1378296  1002.0  Identificação das despesas com ações e serviço...
# 1743512  1002.0  Identificação das despesas com ações e serviço...
# 1914405  1002.0  Identificação das despesas com ações e serviço...
# 2142795  1002.0  Identificação das despesas com ações e serviço...
# 2176652  1002.0  Identificação das despesas com ações e serviço...
#
# [11 rows x 40 columns]

# %%
print(df_despesas.columns)
# Out:
# Index(['municipio', 'codigo_unidade_gestora', 'descricao_unidade_gestora',
#        'numero_empenho', 'data_empenho', 'mes', 'cpf_cnpj', 'nome_credor',
#        'valor_empenhado', 'valor_liquidado', 'valor_pago',
#        'codigo_unidade_orcamentaria', 'descricao_unidade_orcamentaria',
#        'codigo_funcao', 'funcao', 'codigo_subfuncao', 'subfuncao',
#        'codigo_programa', 'programa', 'codigo_acao', 'acao',
#        'codigo_categoria_economica', 'categoria_economica', 'codigo_natureza',
#        'grupo_natureza_despesa', 'codigo_modalidade_aplicacao',
#        'modalidade_aplicacao', 'codigo_elemento_despesa', 'elemento_despesa',
#        'codigo_subelemento', 'codigo_subelemento_exibicao', 'numero_licitacao',
#        'modalidade_licitacao', 'numero_obra', 'historico',
#        'codigo_fonte_recurso', 'descricao_fonte_recurso', 'ano_fonte', 'co',
#        'descricao_co'],
#       dtype='str')

# %%
df_despesas.head(5)
# Out:
#   municipio  codigo_unidade_gestora       descricao_unidade_gestora  \
# 0    Amparo                201009.0  Prefeitura Municipal de Amparo
# 1    Amparo                201009.0  Prefeitura Municipal de Amparo
# 2    Amparo                201009.0  Prefeitura Municipal de Amparo
# 3    Amparo                201009.0  Prefeitura Municipal de Amparo
# 4    Amparo                201009.0  Prefeitura Municipal de Amparo
#
#    numero_empenho data_empenho         mes        cpf_cnpj  \
# 0              10   2025-01-02  01-Janeiro      8086298167
# 1               4   2025-01-02  01-Janeiro    703157000183
# 2               2   2025-01-02  01-Janeiro  18326590000102
# 3               9   2025-01-02  01-Janeiro  42934114000159
# 4               7   2025-01-02  01-Janeiro   9095183000140
#
#                                  nome_credor valor_empenhado valor_liquidado  \
# 0               YISSEL YOANDRA MILANÊS LÒPEZ           1.114           1.114
# 1  CNM- CONFEDERAÇÃO NACIONAL DOS MUNICIPIOS           4.292           4.292
# 2             ANTONIO MARCOS DE MOURA JUNIOR           1.100           1.100
# 3         GUTTYNAIDE FIRMINO NUNES ALCANTARA               0               0
# 4                                   ENERGISA               0               0
#
#    ...                    codigo_subelemento_exibicao  numero_licitacao  \
# 0  ...                                SEM SUBELEMENTO                 0
# 1  ...  OUTROS SERVIÇOS DE TERCEIROS, PESSOA JURÍDICA                 0
# 2  ...  OUTROS SERVIÇOS DE TERCEIROS, PESSOA JURÍDICA                 0
# 3  ...  OUTROS SERVIÇOS DE TERCEIROS, PESSOA JURÍDICA                 0
# 4  ...                                SEM SUBELEMENTO                 0
#
#   modalidade_licitacao  numero_obra  \
# 0        Sem Licitação            0
# 1        Sem Licitação            0
# 2        Sem Licitação            0
# 3        Sem Licitação            0
# 4        Sem Licitação            0
#
#                                            historico  codigo_fonte_recurso  \
# 0  referente valor de empenho para pagamento corr...                   500
# 1  REF. VALOR QUE SE EMPENHA PARA DESPESA COM PAG...                   500
# 2  REFERENTE VALOR QUE SE EMPENHA PARA PAGAMENTO ...                   500
# 3  REFERENTE AOS SERVIÇOS DE COBERTURA JORNALISTI...                   500
# 4  REFERENTE VALOR QUE SE EMPENHA PARA PAGAMENTO ...                   500
#
#                descricao_fonte_recurso  ano_fonte      co  \
# 0  Recursos não vinculados de Impostos          1  1002.0
# 1  Recursos não vinculados de Impostos          1     NaN
# 2  Recursos não vinculados de Impostos          1     NaN
# 3  Recursos não vinculados de Impostos          1     NaN
# 4  Recursos não vinculados de Impostos          1     NaN
#
#                                         descricao_co
# 0  Identificação das despesas com ações e serviço...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 40 columns]

# %%
datas_convertidas = pd.to_datetime(
    df_despesas['data_empenho'], 
    dayfirst=True, 
    format='mixed', 
    errors='coerce'
)

# Filtra o primeiro semestre
df_despesas_1semestre = df_despesas[datas_convertidas.dt.month <= 6].copy()

df_despesas_1semestre.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1061068 entries, 0 to 2383432
# Data columns (total 40 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   municipio                       1058109 non-null  str
#  1   codigo_unidade_gestora          1058109 non-null  float64
#  2   descricao_unidade_gestora       1058109 non-null  str
#  3   numero_empenho                  1061068 non-null  int64
#  4   data_empenho                    1061068 non-null  str
#  5   mes                             1061068 non-null  str
#  6   cpf_cnpj                        1061068 non-null  int64
#  7   nome_credor                     1061068 non-null  str
#  8   valor_empenhado                 1061068 non-null  str
#  9   valor_liquidado                 1061068 non-null  str
#  10  valor_pago                      1061068 non-null  str
#  11  codigo_unidade_orcamentaria     1061068 non-null  int64
#  12  descricao_unidade_orcamentaria  1061068 non-null  str
#  13  codigo_funcao                   1061068 non-null  int64
#  14  funcao                          1061068 non-null  str
#  15  codigo_subfuncao                1061068 non-null  int64
#  16  subfuncao                       1061068 non-null  str
#  17  codigo_programa                 1061068 non-null  int64
#  18  programa                        1061068 non-null  str
#  19  codigo_acao                     1061068 non-null  int64
#  20  acao                            1061068 non-null  str
#  21  codigo_categoria_economica      1061068 non-null  int64
#  22  categoria_economica             1061068 non-null  str
#  23  codigo_natureza                 1061068 non-null  int64
#  24  grupo_natureza_despesa          1061068 non-null  str
#  25  codigo_modalidade_aplicacao     1061068 non-null  int64
#  26  modalidade_aplicacao            1061068 non-null  str
#  27  codigo_elemento_despesa         1061068 non-null  int64
#  28  elemento_despesa                1061068 non-null  str
#  29  codigo_subelemento              1061068 non-null  int64
#  30  codigo_subelemento_exibicao     1061068 non-null  str
#  31  numero_licitacao                1061068 non-null  int64
#  32  modalidade_licitacao            1061068 non-null  str
#  33  numero_obra                     1061068 non-null  int64
#  34  historico                       1061068 non-null  str
#  35  codigo_fonte_recurso            1061068 non-null  int64
#  36  descricao_fonte_recurso         1061068 non-null  str
#  37  ano_fonte                       1061068 non-null  int64
#  38  co                              271926 non-null   float64
#  39  descricao_co                    271926 non-null   str
# dtypes: float64(2), int64(16), str(22)
# memory usage: 1.0 GB

# %%
df_despesas_1semestre.head()
# Out:
#   municipio  codigo_unidade_gestora       descricao_unidade_gestora  \
# 0    Amparo                201009.0  Prefeitura Municipal de Amparo
# 1    Amparo                201009.0  Prefeitura Municipal de Amparo
# 2    Amparo                201009.0  Prefeitura Municipal de Amparo
# 3    Amparo                201009.0  Prefeitura Municipal de Amparo
# 4    Amparo                201009.0  Prefeitura Municipal de Amparo
#
#    numero_empenho data_empenho         mes        cpf_cnpj  \
# 0              10   2025-01-02  01-Janeiro      8086298167
# 1               4   2025-01-02  01-Janeiro    703157000183
# 2               2   2025-01-02  01-Janeiro  18326590000102
# 3               9   2025-01-02  01-Janeiro  42934114000159
# 4               7   2025-01-02  01-Janeiro   9095183000140
#
#                                  nome_credor valor_empenhado valor_liquidado  \
# 0               YISSEL YOANDRA MILANÊS LÒPEZ           1.114           1.114
# 1  CNM- CONFEDERAÇÃO NACIONAL DOS MUNICIPIOS           4.292           4.292
# 2             ANTONIO MARCOS DE MOURA JUNIOR           1.100           1.100
# 3         GUTTYNAIDE FIRMINO NUNES ALCANTARA               0               0
# 4                                   ENERGISA               0               0
#
#    ...                    codigo_subelemento_exibicao  numero_licitacao  \
# 0  ...                                SEM SUBELEMENTO                 0
# 1  ...  OUTROS SERVIÇOS DE TERCEIROS, PESSOA JURÍDICA                 0
# 2  ...  OUTROS SERVIÇOS DE TERCEIROS, PESSOA JURÍDICA                 0
# 3  ...  OUTROS SERVIÇOS DE TERCEIROS, PESSOA JURÍDICA                 0
# 4  ...                                SEM SUBELEMENTO                 0
#
#   modalidade_licitacao  numero_obra  \
# 0        Sem Licitação            0
# 1        Sem Licitação            0
# 2        Sem Licitação            0
# 3        Sem Licitação            0
# 4        Sem Licitação            0
#
#                                            historico  codigo_fonte_recurso  \
# 0  referente valor de empenho para pagamento corr...                   500
# 1  REF. VALOR QUE SE EMPENHA PARA DESPESA COM PAG...                   500
# 2  REFERENTE VALOR QUE SE EMPENHA PARA PAGAMENTO ...                   500
# 3  REFERENTE AOS SERVIÇOS DE COBERTURA JORNALISTI...                   500
# 4  REFERENTE VALOR QUE SE EMPENHA PARA PAGAMENTO ...                   500
#
#                descricao_fonte_recurso  ano_fonte      co  \
# 0  Recursos não vinculados de Impostos          1  1002.0
# 1  Recursos não vinculados de Impostos          1     NaN
# 2  Recursos não vinculados de Impostos          1     NaN
# 3  Recursos não vinculados de Impostos          1     NaN
# 4  Recursos não vinculados de Impostos          1     NaN
#
#                                         descricao_co
# 0  Identificação das despesas com ações e serviço...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 40 columns]

# %% [markdown]
# #### Verificando pares

# %%
pares = [
    ('codigo_funcao', 'funcao'),
    ('codigo_subfuncao', 'subfuncao'),
    ('codigo_programa', 'programa'),
    ('codigo_acao', 'acao'),
    ('codigo_categoria_economica', 'categoria_economica'),
    ('codigo_natureza', 'grupo_natureza_despesa'),
    ('codigo_modalidade_aplicacao', 'modalidade_aplicacao'),
    ('codigo_elemento_despesa', 'elemento_despesa'),
    ('codigo_fonte_recurso', 'descricao_fonte_recurso'),
    ('co', 'descricao_co')
]

for cod, desc in pares:
    inconsistencias = df_despesas_1semestre.groupby(cod)[desc].nunique()
    max_textos = inconsistencias.max()
    print(f"{cod} -> {desc}: {'1:1 Estrito' if max_textos <= 1 else f'INCONSISTENTE ({max_textos} textos)'}")
# Out:
# codigo_funcao -> funcao: 1:1 Estrito
# codigo_subfuncao -> subfuncao: 1:1 Estrito
# codigo_programa -> programa: INCONSISTENTE (101 textos)
# codigo_acao -> acao: INCONSISTENTE (148 textos)
# codigo_categoria_economica -> categoria_economica: 1:1 Estrito
# codigo_natureza -> grupo_natureza_despesa: 1:1 Estrito
# codigo_modalidade_aplicacao -> modalidade_aplicacao: 1:1 Estrito
# codigo_elemento_despesa -> elemento_despesa: 1:1 Estrito
# codigo_fonte_recurso -> descricao_fonte_recurso: 1:1 Estrito
# co -> descricao_co: 1:1 Estrito

# %%
colunas = [
    'codigo_acao', 'acao',
    'codigo_categoria_economica', 'categoria_economica',
    'cpf_cnpj', 'nome_credor',
    'codigo_elemento_despesa', 'elemento_despesa',
    'codigo_fonte_recurso', 'descricao_fonte_recurso',
    'codigo_funcao', 'funcao',
    'numero_licitacao', 'modalidade_licitacao',
    'numero_obra',
    'codigo_modalidade_aplicacao', 'modalidade_aplicacao',
    'municipio',
    'codigo_natureza', 'grupo_natureza_despesa',
    'codigo_programa', 'programa',
    'codigo_unidade_gestora', 'descricao_unidade_gestora'
]

quantidade_elementos = (
    df_despesas_1semestre[colunas]
    .nunique(dropna=False)
    .sort_values(ascending=False)
    .rename('quantidade_elementos_diferentes')
    .reset_index()
    .rename(columns={'index': 'coluna'})
)

quantidade_elementos
# Out:
#                          coluna  quantidade_elementos_diferentes
# 0                   nome_credor                           183346
# 1                      cpf_cnpj                           170232
# 2                          acao                            12105
# 3              numero_licitacao                             3107
# 4                      programa                             2701
# 5                   codigo_acao                             1116
# 6                   numero_obra                              688
# 7        codigo_unidade_gestora                              623
# 8     descricao_unidade_gestora                              623
# 9               codigo_programa                              512
# 10                    municipio                              224
# 11         codigo_fonte_recurso                               65
# 12      descricao_fonte_recurso                               65
# 13      codigo_elemento_despesa                               50
# 14             elemento_despesa                               50
# 15         modalidade_licitacao                               29
# 16                codigo_funcao                               26
# 17                       funcao                               26
# 18  codigo_modalidade_aplicacao                               13
# 19         modalidade_aplicacao                               13
# 20       grupo_natureza_despesa                                6
# 21              codigo_natureza                                6
# 22   codigo_categoria_economica                                2
# 23          categoria_economica                                2

# %%
# Busca por cpf_cnpj = 191 ou 00000000000191
# Normaliza para comparar apenas dígitos e remover zeros à esquerda

s = (
    df_despesas_1semestre['cpf_cnpj']
    .astype(str)
    .str.replace(r'\D', '', regex=True)
    .str.replace(r'^0+(?=\d)', '', regex=True)
)

mask = s.eq('191')

resultado = df_despesas_1semestre.loc[mask].copy()

print(f"Registros encontrados: {len(resultado):,}")
if not resultado.empty:
    display(resultado[['municipio', 'cpf_cnpj', 'nome_credor', 'valor_empenhado', 'valor_liquidado', 'valor_pago']].head(20))
else:
    print("Nenhum registro com cpf_cnpj = 191 ou 00000000000191 encontrado.")
# Out:
# Registros encontrados: 4,274
#                municipio  cpf_cnpj                nome_credor valor_empenhado  \
# 1462               Sousa       191            BANCO DO BRASIL            13,6
# 1465               Sousa       191            BANCO DO BRASIL             5,8
# 2589             Cuitegi       191         BANCO DO BRASIL SA          556,96
# 3382  São José de Caiana       191         BANCO DO BRASIL SA             5,8
# 3386  São José de Caiana       191         BANCO DO BRASIL SA             6,8
# 3387  São José de Caiana       191         BANCO DO BRASIL SA             3,4
# 3388  São José de Caiana       191         BANCO DO BRASIL SA            40,8
# 3557            Mataraca       191  BANCO DO BRASIL -  PASEP.           26,11
# 3562            Mataraca       191  BANCO DO BRASIL -  PASEP.        6.006,92
# 3568            Mataraca       191  BANCO DO BRASIL -  PASEP.          398,95
# 3574            Mataraca       191  BANCO DO BRASIL -  PASEP.           42,83
# 3621           Itabaiana       191            BANCO DO BRASIL        7.814,14
# 5078           Alagoinha       191        BANCO DO BRASIL S/A             5,8
# 5097           Alagoinha       191        BANCO DO BRASIL S/A            27,2
# 5098           Alagoinha       191        BANCO DO BRASIL S/A            13,6
# 5100           Alagoinha       191        BANCO DO BRASIL S/A             6,8
# 5171          Mamanguape       191        BANCO DO BRASIL S/A             5,8
# 5172          Mamanguape       191        BANCO DO BRASIL S/A               0
# 6088          Mamanguape       191        BANCO DO BRASIL S/A             5,8
# 6575             Cuitegi       191         BANCO DO BRASIL SA               0
#
#      valor_liquidado valor_pago
# 1462            13,6       13,6
# 1465             5,8        5,8
# 2589          556,96     556,96
# 3382             5,8        5,8
# 3386             6,8        6,8
# 3387             3,4        3,4
# 3388            40,8       40,8
# 3557           26,11      26,11
# 3562        6.006,92   6.006,92
# 3568          398,95     398,95
# 3574           42,83      42,83
# 3621        7.814,14   7.814,14
# 5078             5,8        5,8
# 5097            27,2       27,2
# 5098            13,6       13,6
# 5100             6,8        6,8
# 5171             5,8        5,8
# 5172               0          0
# 6088             5,8        5,8
# 6575               0          0

# %% [markdown]
# #### Exportar csv
# - 5 primeiras linhas

# %%
""" df_despesas_1semestre.head(5).to_csv(
    'despesas_amostra.csv', 
    index=False, 
    sep=';', 
    encoding='utf-8-sig'
) """

# %% [markdown]
# ### Conectando no Mysql
# - Sintaxe: 'mysql+pymysql://usuario:senha@localhost:3306/nome_do_banco'
# - Docker: 'mysql+pymysql://usuario:senhasegura@localhost:3307/empenhos_2025'

# %%
engine = create_engine('mysql+pymysql://usuario:senhasegura@localhost:3307/modelagem')

# %% [markdown]
# ### Despesas
# - 2025 -> 2.387.532 linhas e 40 colunas
# - 2025 (1 semestre) -> 1.068.148 linhas e 40 colunas

# %% [markdown]
# #### Função

# %%
def normalizar_empenhos(df: pd.DataFrame) -> dict:
    # -------------------------------------------------------------------------
    # 0. Limpeza de Nomes de Colunas (Remove caractere BOM \ufeff da coluna municipio)
    # -------------------------------------------------------------------------
    df.columns = df.columns.str.replace('\ufeff', '').str.strip()

    # -------------------------------------------------------------------------
    # 1FN: Ajustes de Tipagem e Conversão
    # -------------------------------------------------------------------------
    colunas_valores = ['valor_empenhado', 'valor_liquidado', 'valor_pago']
    for col in colunas_valores:
        if col in df.columns and (df[col].dtype == 'object' or df[col].dtype == 'string'):
            df[col] = (
                df[col]
                .astype(str)
                .str.replace('.', '', regex=False)
                .str.replace(',', '.', regex=False)
            )
            df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0.0)

    if 'data_empenho' in df.columns:
        df['data_empenho'] = pd.to_datetime(df['data_empenho'], errors='coerce')

    # -------------------------------------------------------------------------
    # 2FN e 3FN: Extração das Tabelas de Dimensão
    # -------------------------------------------------------------------------
    dim_unidade_gestora = (
        df[['codigo_unidade_gestora', 'descricao_unidade_gestora', 'municipio']]
        .drop_duplicates(subset=['codigo_unidade_gestora'])
        .reset_index(drop=True)
    )

    dim_unidade_orcamentaria = (
        df[['codigo_unidade_orcamentaria', 'descricao_unidade_orcamentaria']]
        .drop_duplicates(subset=['codigo_unidade_orcamentaria'])
        .reset_index(drop=True)
    )

    dim_credor = (
        df[['cpf_cnpj', 'nome_credor']]
        .drop_duplicates(subset=['cpf_cnpj'])
        .reset_index(drop=True)
    )

    dim_funcao = (
        df[['codigo_funcao', 'funcao']]
        .drop_duplicates(subset=['codigo_funcao'])
        .reset_index(drop=True)
    )

    dim_subfuncao = (
        df[['codigo_subfuncao', 'subfuncao']]
        .drop_duplicates(subset=['codigo_subfuncao'])
        .reset_index(drop=True)
    )

    dim_programa = (
        df[['codigo_programa', 'programa']]
        .drop_duplicates(subset=['codigo_programa'])
        .reset_index(drop=True)
    )

    dim_acao = (
        df[['codigo_acao', 'acao']]
        .drop_duplicates(subset=['codigo_acao'])
        .reset_index(drop=True)
    )

    dim_categoria_economica = (
        df[['codigo_categoria_economica', 'categoria_economica']]
        .drop_duplicates(subset=['codigo_categoria_economica'])
        .reset_index(drop=True)
    )

    dim_natureza = (
        df[['codigo_natureza', 'grupo_natureza_despesa']]
        .drop_duplicates(subset=['codigo_natureza'])
        .reset_index(drop=True)
    )

    dim_modalidade_aplicacao = (
        df[['codigo_modalidade_aplicacao', 'modalidade_aplicacao']]
        .drop_duplicates(subset=['codigo_modalidade_aplicacao'])
        .reset_index(drop=True)
    )

    dim_elemento_despesa = (
        df[['codigo_elemento_despesa', 'elemento_despesa']]
        .drop_duplicates(subset=['codigo_elemento_despesa'])
        .reset_index(drop=True)
    )

    dim_fonte_recurso = (
        df[['codigo_fonte_recurso', 'descricao_fonte_recurso']]
        .drop_duplicates(subset=['codigo_fonte_recurso'])
        .reset_index(drop=True)
    )

    dim_co = (
        df[['co', 'descricao_co']]
        .dropna(subset=['co'])
        .drop_duplicates(subset=['co'])
        .reset_index(drop=True)
    )

    # -------------------------------------------------------------------------
    # Tabela Fato
    # -------------------------------------------------------------------------
    colunas_fato = [
        'numero_empenho', 'ano_referencia', 'data_empenho', 'mes',
        'codigo_unidade_gestora', 'codigo_unidade_orcamentaria', 'cpf_cnpj',
        'codigo_funcao', 'codigo_subfuncao', 'codigo_programa', 'codigo_acao',
        'codigo_categoria_economica', 'codigo_natureza', 'codigo_modalidade_aplicacao',
        'codigo_elemento_despesa', 'codigo_subelemento', 'codigo_subelemento_exibicao',
        'codigo_fonte_recurso', 'co', 'numero_licitacao', 'modalidade_licitacao',
        'numero_obra', 'valor_empenhado', 'valor_liquidado', 'valor_pago',
        'historico', 'ano_fonte', 'arquivo_origem'
    ]

    fato_empenhos = df[[col for col in colunas_fato if col in df.columns]].copy()

    return {
        'fato_empenhos': fato_empenhos,
        'dim_unidade_gestora': dim_unidade_gestora,
        'dim_unidade_orcamentaria': dim_unidade_orcamentaria,
        'dim_credor': dim_credor,
        'dim_funcao': dim_funcao,
        'dim_subfuncao': dim_subfuncao,
        'dim_programa': dim_programa,
        'dim_acao': dim_acao,
        'dim_categoria_economica': dim_categoria_economica,
        'dim_natureza': dim_natureza,
        'dim_modalidade_aplicacao': dim_modalidade_aplicacao,
        'dim_elemento_despesa': dim_elemento_despesa,
        'dim_fonte_recurso': dim_fonte_recurso,
        'dim_co': dim_co
    }

# %% [markdown]
# #### Normalizando

# %%
# modelos_2025 = normalizar_empenhos(df_despesas)
modelos_2025_1semestre = normalizar_empenhos(df_despesas_1semestre)

# %%
del df_despesas
del df_despesas_1semestre
gc.collect()
# Out:
# 16563

# %% [markdown]
# #### Tabelas para o MySQL
# - Escolha modelos_2025 ou modelos_2025_1semestre

# %%
for nome_tabela, df_tabela in modelos_2025_1semestre.items():
    print(f"Exportando {nome_tabela} ({len(df_tabela):,} linhas)...")
    df_tabela.to_sql(
        name=nome_tabela,
        con=engine,
        if_exists='replace',
        index=False,
        chunksize=20000
    )

print("Dados carregados no MySQL local!")
# Out:
# Exportando fato_empenhos (1,068,148 linhas)...
# Exportando dim_unidade_gestora (622 linhas)...
# Exportando dim_unidade_orcamentaria (519 linhas)...
# Exportando dim_credor (168,771 linhas)...
# Exportando dim_funcao (26 linhas)...
# Exportando dim_subfuncao (88 linhas)...
# Exportando dim_programa (513 linhas)...
# Exportando dim_acao (1,104 linhas)...
# Exportando dim_categoria_economica (2 linhas)...
# Exportando dim_natureza (6 linhas)...
# Exportando dim_modalidade_aplicacao (14 linhas)...
# Exportando dim_elemento_despesa (50 linhas)...
# Exportando dim_fonte_recurso (64 linhas)...
# Exportando dim_co (15 linhas)...
# Dados carregados no MySQL local!

# %% [markdown]
# ### Despesas + Receitas
